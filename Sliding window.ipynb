# %%
import os
import matplotlib.pyplot as plt

# %%
frames = os.listdir('./Object Detection/')

# %%
frames = sorted(frames[0 : len(frames) - 1])

# %%
len(frames)
# Out:
# 2499

# %%
count = 1
for i in frames:
    path = "./Object Detection/" + str(i)
    print(i)
# Out:
# 84_0.png
# 84_1.png
# 84_10.png
# 84_100.png
# 84_1000.png
# 84_1001.png
# 84_1002.png
# 84_1003.png
# 84_1004.png
# 84_1005.png
# 84_1006.png
# 84_1007.png
# 84_1008.png
# 84_1009.png
# 84_101.png
# 84_1010.png
# 84_1011.png
# 84_1012.png
# 84_1013.png
# 84_1014.png
# 84_1015.png
# 84_1016.png
# 84_1017.png
# 84_1018.png
# 84_1019.png
# 84_102.png
# 84_1020.png
# 84_1021.png
# 84_1022.png
# 84_1023.png
# 84_1024.png
# 84_1025.png
# 84_1026.png
# 84_1027.png
# 84_1028.png
# 84_1029.png
# 84_103.png
# 84_1030.png
# 84_1031.png
# 84_1032.png
# 84_1033.png
# 84_1034.png
# 84_1035.png
# 84_1036.png
# 84_1037.png
# 84_1038.png
# 84_1039.png
# 84_104.png
# 84_1040.png
# 84_1041.png
# 84_1042.png
# 84_1043.png
# 84_1044.png
# 84_1045.png
# 84_1046.png
# 84_1047.png
# 84_1048.png
# 84_1049.png
# 84_105.png
# 84_1050.png
# 84_1051.png
# 84_1052.png
# 84_1053.png
# 84_1054.png
# 84_1055.png
# 84_1056.png
# 84_1057.png
# 84_1058.png
# 84_1059.png
# 84_106.png
# 84_1060.png
# 84_1061.png
# ...
